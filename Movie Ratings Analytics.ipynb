# %%
import pandas as pd 
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\kush and kittu\\Desktop\\KUSHAGR\\PYTHON'

# %%
movies=pd.read_csv('P4-Movie-Ratings.csv')

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.Film=movies.Film.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticsRatings   559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   Budget           559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movies.Genre=movies.Genre.astype('category')

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns=['Film', 'Genre', 'CriticsRatings', 'AudienceRatings',\
       'Budget', 'Year']

# %%
movies.Year=movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticsRatings   559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   Budget           559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movies.describe()
# Out:
#        CriticsRatings  AudienceRatings      Budget
# count      559.000000       559.000000  559.000000
# mean        47.309481        58.744186   50.236136
# std         26.413091        16.826887   48.731817
# min          0.000000         0.000000    0.000000
# 25%         25.000000        47.000000   20.000000
# 50%         46.000000        58.000000   35.000000
# 75%         70.000000        72.000000   65.000000
# max         97.000000        96.000000  300.000000

# %%
from matplotlib import pyplot as plt 
import seaborn as sns 
# %matplotlib inline 
import warnings 
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=9,4

# %%
#jointplot

# %%
#-----------------------

# %%
a=sns.jointplot(data=movies,x='AudienceRatings',y='CriticsRatings',)
sns.set_style("darkgrid")
marginal_kws={'hist_kws': {'edgecolor': 'Black'}}
plt.show()

# %%
a=sns.jointplot(data=movies,x='AudienceRatings',y='CriticsRatings',kind='hex',height=6)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
#histogram

# %%
sns.distplot(movies.AudienceRatings)
plt.show()

# %%
sns.set_style('white')
n=plt.hist(movies.AudienceRatings,bins=17)

# %%
sns.set_style('darkgrid')
m=plt.hist(movies.AudienceRatings,bins=17)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticsRatings   559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   Budget           559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movies.Genre.cat.categories #saves space of each row copared to .unique
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.Genre.unique
# Out:
# <bound method Series.unique of 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): [Action, Adventure, Comedy, Drama, Horror, Romance, Thriller]>

# %%
plt.hist(movies[movies.Genre =='Action'].Budget,bins=17)
plt.show()

# %%
plt.hist([movies[movies.Genre =='Action'].Budget,\
          movies[movies.Genre =='Comedy'].Budget,\
          movies[movies.Genre =='Thriller'].Budget],\
          bins=17,stacked=True)
plt.show()

# %%
for genr in movies.Genre.cat.categories:
    print(genr)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list1=list()
for genr in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre ==genr].Budget)
print(list1)
# Out:
# [2       20
# 5      200
# 15      35
# 29      20
# 30      20
#       ...
# 531    130
# 542     35
# 546    150
# 547    160
# 557     24
# Name: Budget, Length: 154, dtype: int64, 1      105
# 3       18
# 19     200
# 21      45
# 24      40
# 32      78
# 46      20
# 65      38
# 68     140
# 130     73
# 165     12
# 166    125
# 167    250
# 168    150
# 176     36
# 178    150
# 192     70
# 193     60
# 241     60
# 272     37
# 341     19
# 363     70
# 386    130
# 401    155
# 459     59
# 463     25
# 506     38
# 540    100
# 548     60
# Name: Budget, dtype: int64, 0       8
# 4      20
# 6      30
# 8      28
# 9       8
#        ..
# 552    80
# 553    22
# 554    50
# 555    18
# 558    80
# Name: Budget, Length: 172, dtype: int64, 10     30
# 11     20
# 13      7
# 18      8
# 23     20
#        ..
# 529    66
# 532    38
# 534    21
# 541    15
# 545     2
# Name: Budget, Length: 101, dtype: int64, 7      32
# 12     35
# 20     40
# 28      5
# 59     26
# ...

# %%
list1=list()
mylabels=[]
for genr in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre ==genr].Budget)
    mylabels.append(genr)
plt.hist(list1,bins=30,stacked=True, rwidth=1,label=mylabels)
plt.legend()
plt.show()

# %% [markdown]
# ---

# %%
#KDE

# %%
sns.lmplot(data=movies,x='CriticsRatings',y='AudienceRatings',fit_reg=False,size=7,hue='Genre',scatter_kws={'s':30})
plt.show()

# %%
#kde plot
sns.kdeplot(movies.CriticsRatings,movies.AudienceRatings,shade=True,shade_lowest=False,cmap='Reds')
plt.show()

# %%
#kde plot with sharp edges 
k1=sns.kdeplot(movies.CriticsRatings,movies.AudienceRatings,shade=True,shade_lowest=False,cmap='Reds')
k1b=sns.kdeplot(movies.CriticsRatings,movies.AudienceRatings,cmap='Reds')
plt.show()

# %%
#subplots()

# %%
sns.kdeplot(movies.Budget,movies.AudienceRatings)
plt.show()

# %%
sns.kdeplot(movies.Budget,movies.CriticsRatings)
plt.show()

# %%
f,axes=plt.subplots(1,2,figsize=(12,6),sharey=True,sharex=True)
k1=sns.kdeplot(movies.Budget,movies.AudienceRatings,ax=axes[0])
k2=sns.kdeplot(movies.Budget,movies.CriticsRatings,ax=axes[1])
k1.set(xlim=(-20,160))
plt.show()

# %%
movies[movies.Genre=='Thriller']
# Out:
#                                    Film     Genre  Rotten Tomatoes Ratings %  \
# 25                    American Gangster  Thriller                         79
# 72                            Contagion  Thriller                         84
# 95                            Disturbia  Thriller                         67
# 105                               Drive  Thriller                         93
# 179                         I Am Legend  Thriller                         69
# 180                    I Am Number Four  Thriller                         32
# 189                             In Time  Thriller                         38
# 225                           Limitless  Thriller                         69
# 237                         Margin Call  Thriller                         86
# 243                     Michael Clayton  Thriller                         90
# 253                          Mr. Brooks  Thriller                         56
# ...

# %%
#violinplots
#violinplots v/s boxplots

# %%
sns.boxplot(data=movies,y='CriticsRatings',x='Genre')
plt.show()

# %%
sns.violinplot(data=movies,y='CriticsRatings',x='Genre') #wider area means more amount of movies have got ratings of same range
plt.show()

# %%
sns.boxplot(data=movies[movies.Genre=='Drama'],y='CriticsRatings',x='Year')
plt.show()

# %%
sns.violinplot(data=movies[movies.Genre=='Drama'],y='CriticsRatings',x='Year')
plt.show()

# %%
#Creating a facet grid

# %%
sns.set_style("dark")
g=sns.FacetGrid(movies , row='Genre',col='Year',hue='Genre')

# %%
g=sns.FacetGrid(movies , row='Genre',col='Year',hue='Genre')
g.map(plt.scatter,'CriticsRatings','AudienceRatings')
plt.show()

# %%
h=sns.FacetGrid(movies , row='Genre',col='Year',hue='Genre')
h.map(plt.hist,'Budget')
plt.show()

# %%
#back to scatterplot
#adding coordinates and diagonals 
g=sns.FacetGrid(movies , row='Genre',col='Year',hue='Genre')
kws=dict(s=50,linewidth=0.5,edgecolor='black')
g.map(plt.scatter,'CriticsRatings','AudienceRatings',**kws)
g.set(xlim=(0,100),ylim=(0,100))
for ax in g.axes.flat:
    ax.plot((0,100),(0,100),c='gray',ls='--')
g.add_legend()
plt.show()

# %%
kws
# Out:
# {'s': 50, 'linewidth': 0.5, 'edgecolor': 'black'}

# %% [markdown]
# ---

# %%
#building a dashboard

# %%
##for plots present in seaborn 
sns.set_style("darkgrid")
f,axes=plt.subplots(2,2,figsize=(12,6))
k1=sns.kdeplot(movies.Budget,movies.AudienceRatings,ax=axes[0,0])
k2=sns.kdeplot(movies.Budget,movies.CriticsRatings,ax=axes[0,1])
k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
sns.violinplot(data=movies[movies.Genre=='Drama'],y='CriticsRatings',x='Year',ax=axes[1,0])
##sns.regplot(data=movies,x='CriticsRatings',y='AudienceRatings',fit_reg=False,ax=axes[1,1]) instead of lmplot\
## for dashboard use regplot
##axes[1,1].hist(movies[movies.Genre =='Action'].Budget,bins=17) for plots not present in seaborn
k4=sns.kdeplot(movies.CriticsRatings,movies.AudienceRatings,shade=True,shade_lowest=False,cmap='Reds',ax=axes[1,1])
k4b=sns.kdeplot(movies.CriticsRatings,movies.AudienceRatings,cmap='Reds',ax=axes[1,1]) #two graphs can be overlapped 
plt.show()

# %%
##styling up the dashboard
sns.set_style("dark",{"axes.facecolor":"black"}) #called a dictionary for black background
f,axes=plt.subplots(2,2,figsize=(18,9))
#plot[0,0]
k1=sns.kdeplot(movies.Budget,movies.AudienceRatings,ax=axes[0,0],shade=True,shade_lowest=True,cmap='inferno')
k1b=sns.kdeplot(movies.Budget,movies.AudienceRatings,ax=axes[0,0],cmap='cool')
#plot[0,1]
k2=sns.kdeplot(movies.Budget,movies.CriticsRatings,ax=axes[0,1],shade=True,shade_lowest=True,cmap='inferno')
k2=sns.kdeplot(movies.Budget,movies.CriticsRatings,ax=axes[0,1],cmap='cool')
#coordinates
k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
#plot[1,0]
sns.violinplot(data=movies,y='Budget',x='Year',ax=axes[1,0],palette='YlOrRd')
#plot[1,1]
k4=sns.kdeplot(movies.CriticsRatings,movies.AudienceRatings,shade=True,shade_lowest=False,cmap='Blues',ax=axes[1,1])
k4b=sns.kdeplot(movies.CriticsRatings,movies.AudienceRatings,cmap='gist_gray_r',ax=axes[1,1]) #two graphs can be overlapped 
plt.show()

# %%
#Thematic edits

# %%
list1=list()
mylabels=[]
for genr in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre ==genr].Budget)
    mylabels.append(genr)
sns.set_style("whitegrid")
fig,ax=plt.subplots()
fig.set_size_inches(11.7,8.27)
plt.title("Movie Budget Distribution",fontsize=30,color='Darkblue',fontname='Arial')
plt.ylabel('Number of Movies',fontsize=25,color='Red')
plt.xlabel('Budget',fontsize=25,color='Green')
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)
plt.hist(list1,bins=30,stacked=True, rwidth=1,label=mylabels)
plt.legend(frameon=True ,fancybox=True ,framealpha=1,shadow=True,prop={'size':20})
plt.show()
